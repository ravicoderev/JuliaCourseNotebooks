# %%
using Plots
pyplot()
# Out:
# INFO: Recompiling stale cache file /Users/ravikumar/.julia/lib/v0.6/PyCall.ji for module PyCall.
# INFO: Recompiling stale cache file /Users/ravikumar/.julia/lib/v0.6/PyPlot.ji for module PyPlot.
# Plots.PyPlotBackend()

# %%
x = collect(1:7)
y(x) = 2 - 2x + x^2/4
# Out:
# y (generic function with 1 method)

# %%
plot(x,y)

# %%
plot!(x, y, marker = :diamond, linewidth=2)

# %%
plot!(title = "Sample plot", leg=false)

# %%
x = [1 2 3 4 5 6]'
y = (x-3).^2/4
plot(x,y, marker = :hex, leg=false)
plot!(title="Plot for graded quiz", linewidth = 2, linecolor=:black)
# Out:
# invalid redefinition of constant y
