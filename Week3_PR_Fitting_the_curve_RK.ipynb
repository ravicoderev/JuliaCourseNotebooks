# %% [markdown]
# # Week 3 - Fitting a curve

# %%
# You may need this setup
using Plots
pyplot()
# Out:
# Plots.PyPlotBackend()

# %% [markdown]
# Import the supplied data representing 15 pairs to x- and y-values.

# %%
data_tofit = [1.6800483    -1.641695388; 
              0.501309281  -0.977697538; 
              1.528012113   0.52771122;
              1.70012253    1.711524991; 
              1.992493625   1.891000015;
              2.706075824  -0.463427794;
              2.994931927  -0.443566619;
              3.491852811  -1.275179133;
              3.501191722  -0.690499597;
              4.459924502  -5.516130799;
              4.936965851  -6.001703074;
              5.023289852  -8.36416901;
              5.04233698   -7.924477517;
              5.50739285  -10.77482371;
              5.568665171 -10.9171878]

# Create the arrays x and y, assigning x the first column of data_tofit and y the second column
# Out:
# 15×2 Array{Float64,2}:
#  1.68005    -1.6417
#  0.501309   -0.977698
#  1.52801     0.527711
#  1.70012     1.71152
#  1.99249     1.891
#  2.70608    -0.463428
#  2.99493    -0.443567
#  3.49185    -1.27518
#  3.50119    -0.6905
#  4.45992    -5.51613
#  4.93697    -6.0017
#  5.02329    -8.36417
#  5.04234    -7.92448
#  5.50739   -10.7748
#  5.56867   -10.9172

# %%
# Write a ‘For’ loop to print out all the values of data\_tofitdata_tofit. The result should be numbers in 15 rows and two columns.
for x = 1:15     
   println(data_tofit[x,:])
end
# Out:
# [1.68005, -1.6417]
# [0.501309, -0.977698]
# [1.52801, 0.527711]
# [1.70012, 1.71152]
# [1.99249, 1.891]
# [2.70608, -0.463428]
# [2.99493, -0.443567]
# [3.49185, -1.27518]
# [3.50119, -0.6905]
# [4.45992, -5.51613]
# [4.93697, -6.0017]
# [5.02329, -8.36417]
# [5.04234, -7.92448]
# [5.50739, -10.7748]
# [5.56867, -10.9172]

# %% [markdown]
# Then we do a scatterplot, this gives us the points the line must go through.

# %%
# Assign the values from the first column of data_tofit into a new array called xx. Similarly assign the values from the second column of data\_tofitdata_tofit into a new array called yy.
x = data_tofit[:,1]
println(x)
y = data_tofit[:,2]
println(y)
# Out:
# [1.68005, 0.501309, 1.52801, 1.70012, 1.99249, 2.70608, 2.99493, 3.49185, 3.50119, 4.45992, 4.93697, 5.02329, 5.04234, 5.50739, 5.56867]
# [-1.6417, -0.977698, 0.527711, 1.71152, 1.891, -0.463428, -0.443567, -1.27518, -0.6905, -5.51613, -6.0017, -8.36417, -7.92448, -10.7748, -10.9172]

# %%
# Plot the x and y data points using a scatter plot of the x and y array variables
plot(x, y, line=:scatter, legend=:false, title="Scatter plot of the x and y array variables")

# %% [markdown]
# For the line, we need a function, which we now define. Note that the parameters a, b, c need not be passed to the function: we will keep resetting them to try to improve the fit.

# %%
# Create a function called parabfit, with x as the argument, returning a*x^2 + b*x + c
function parabfit(x) 
    return (a*x^2) + (b*x) + c
end
# Out:
# parabfit (generic function with 2 methods)

# %% [markdown]
# Let's check that we do get a reasonable parabola. Choose your own interval [xmin, xmax] and parameters a, b, c. If it looks too much like a straight line, chance your choices until it does.

# %%
# Create variables a, b and c, assigning each the value 1
a = 1
b = 1
c = 1

# Plot the function parabfit, for x values between -5 and 5 
plot(parabfit,-5,5)

# %% [markdown]
# Now we choose a, b, c and plot the curve together with the points.
#
# Note that by looking at where the data points lie, we can deduce some of the properties for a, b, c, as follows.
#
# The plot must have a y-intersection that is close to 0, so c is close to 0. Also, the parabola is open downwards, so a must be negative. Finally, it has its maximum at a positive x, so b must be positive.
#
# Use plot() to start with the scatter plot and plot!() to add the curve for parabfit. (There are other ways to do this ...)

# %%
# More plot!() tries.
# a,b,c = 

#a,b,c = 2,3,2
#a,b,c = 4,3,2
#a,b,c = 2,2,-2
#a,b,c = -4,2,-2
#a,b,c = -2,3,-1.8
#a,b,c = -1.5,3,-2


a,b,c = -0.5,2,2


plot(x, y, line=:scatter, legend=:false, title="Parabola Fit")
plot!(parabfit,-5,5)

# %% [markdown]
# 1. Started with all positive numbers.
# 2. Regular parabola with the scatter plots outside
#    * #a,b,c = 2,3,2
#    * #a,b,c = 4,3,2
# 3. Made 'c' negative but nothing much changed despite multiple negative values.
#    * #a,b,c = 2,2,-2
# 4. Changed 'a' to negative which inverted the parabola with scatter plots above
#    * #a,b,c = -4,2,-2
# 5. After multiple attempts and even going back and forth with postive nad negative for 'a' there was reasonable fits with below values
#    * #a,b,c = -2,3,-1.8
#    * #a,b,c = -1.5,3,-2
#    * #a,b,c = -0.9,3.3,-1.8
# 6. Stopped the trials.
